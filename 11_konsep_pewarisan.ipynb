// %% [markdown]
// <a href="https://colab.research.google.com/github/rahmadsa/Pemrograman-Java/blob/main/11_konsep_pewarisan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %% [markdown]
// ---

// %% [markdown]
// ### Petunjuk Penting !!
//
// ####  Lakukan Inisialisasi Java Kompailer untuk Google Colab
// Notebook ini menggunakan Java di Google Colaboratory sebagai kompailer. Untuk itu lakukan dua langkah dibawah ini sebelum anda bekerja dengan notebook ini
//
// 1. Jalankan perintah pada cell diabawah ini (klik tombol run atau tekan tombol `Shift`+`Enter` secara bersamaan)

// %%
//init java please...

// %% [markdown]
// 2. Kemudian refresh halaman notebook (page) (tekan tombol `F5`) atau that. atau tekan tombol refresh/reload.

// %% [markdown]
// ---

// %% [markdown]
// # 13. Konsep Pewarisan
//
// Dalam PBO sebuah class atau objek akan saling berhubungan dengan class yang lain.
// Salah satu bentuk hubungannya adalah inheritance (pewarisan). Hubungan ini seperti hubungan keluarga antara orang tua(induk) dan anak.
//
//
// ## 13.1 Tujuan
// Setelah mengikuti meteri ini mahasiswa diharapkan dapat :
// 1. Mahasiswa memahami konsep pewarisan dalam PBO
// 2. Mahasiswa mampu menerapkan konnsep pewarisan dalam PBO

// %% [markdown]
// ## 13.2 Uraian Materi
// Sebuah class di Java, bisa memiliki satu atau lebih keturunan atau class anak. Class anak akan memiliki warisan properti dan method dari class ibu.

// %% [markdown]
// ### 13.2.1 Dasar Penggunaan Inheritance
//
// Kasus dalam pembuatan Game Hantu, kita akan membuat class-class musuh dengan perilaku yang berbeda.
//
// ![UML Game Hantu](https://github.com/rahmadsa/Pemrograman-Java/blob/84fc2b816c5c4a34c3d228c1da8cd593c74823f0/images/UMLZombiPocongBurung.png?raw=true)
//
//
//
// Lalu kita membuat kode untuk masing-masing kelas seperti ini:
// 1. **Kode Class Zombie**
// ```javascript
// class Zombie {
//     String name;
//     int hp;
//     int attackPoin;
//
//     void attack(){
//         // ...
//     }
//
//     void walk(){
//         //...
//     }
// }
// ```
// 2. **Kode Class Pocong**
//
// ```javascript
// class Pocong {
//     String name;
//     int hp;
//     int attackPoin;
//
//     void attack(){
//         // ...
//     }
//
//     void jump(){
//         //...
//     }
// }
// ```
//
// 3. **Kode Class Burung**
//
// ```javascript
// class Burung {
//     String name;
//     int hp;
//     int attackPoin;
//
//     void attack(){
//         // ...
//     }
//
//     void walk(){
//         //...
//     }
//
//     void jump(){
//         //...
//     }
//
//     void fly(){
//         //...
//     }
// }
// ```

// %% [markdown]
// ### 13.2.1 Penerapan Inheritance
// Pembuatan Struktur class seperti diatas diperbolehkan. Tetapi tidak efektif, karena kita menulis berulang-ulang properti dan method yang sama.   Kemudian bagaimana solusinya?
// Agar lebih efektif kita harus menggunakan inheritance.
// Mari kita analisis kompunen – kompunen dari class – class  yang sama:
//
// ![UML Inheritance Game Hantu](https://github.com/rahmadsa/Pemrograman-Java/blob/84fc2b816c5c4a34c3d228c1da8cd593c74823f0/images/UMLZombiPocongBurungSelect.png?raw=true)
//
// Setelah kita implementasikan penggunaan konsep pewarisan maka strukturnya menjadi seperti berikut:
// ![UML Inheritance Game Hantu](https://github.com/rahmadsa/Pemrograman-Java/blob/84fc2b816c5c4a34c3d228c1da8cd593c74823f0/images/UMLZombiPocongBurungInherits.png?raw=true)
//
// Konsep inheritance dalam diagram UML digambarkan dengan garis hubung Generalization.
//
// Class Enemy adalah class induk yang memiliki anak Zombie, Pocong, dan Burung. Apapun properti yang ada di class induk, akan dimiliki juga oleh class anak.
//
// Berikut ini implementasi kode di java  seperti berikut class Enemy.
//
// ```javascript
// class Enemy {
//     String name;
//     int hp;
//     int attackPoin;
//
//     void attack(){
//         System.out.println("Serang!");
//     }
// }
//
// ```
// Pada class anak, kita menggunakan kata kunci **extends** untuk menyatakan kalau dia adalah class turunan dari Enemy.
//
// Struktur class Zombie adalah sebagai berikut.
//
// ```javascript
//
// class Zombie extends Enemy {
//     void walk(){
//         System.out.println("Zombie jalan-jalan");
//     }
// }
// ```
//
// Struktur class Pocong adalah sebagai berikut.
//
// ```javascript
// class Pocong extends Enemy {
//     void jump(){
//         System.out.println("loncat-loncat!");
//     }
// }
//
// ```
// Sedangkan struktur class Burung adalah sebagai berikut.
//
// ```javascript
// class Burung extends Enemy {
//     void walk(){
//         System.out.println("Burung berjalan");
//     }
//     void jump(){
//         System.out.println("Burung loncat-loncat");
//     }
//     void fly(){
//         System.out.println("Burung Terbang...");
//     }
// }
//
// ```
// Lalu, bila kita ingin membuat objek dari class-class tersebut, Kita bisa melakukan instanisasi seperti ini:
//
//
// ```javascript
// Enemy monster = new Enemy();
// Zombie zumbi = new Zombie();
// Pocong hantuPocong = new Pocong();
// Burung garuda = new Burung();
//
// ```
//
// Kode lengkapnya adalah sebagai berikut.
//
// **Program 13.1 Penerapan Pewarisan**
//
// ```javascript
// class Enemy {
//     String name;
//     int hp;
//     int attackPoin;
//
//     void attack(){
//         System.out.println("Serang!");
//     }
// }
//
// class Zombie extends Enemy {
//     void walk(){
//         System.out.println("Zombie jalan-jalan");
//     }
// }
//
// class Pocong extends Enemy {
//     void jump(){
//         System.out.println("loncat-loncat!");
//     }
// }
//
// class Burung extends Enemy {
//     void walk(){
//         System.out.println("Burung berjalan");
//     }
//     void jump(){
//         System.out.println("Burung loncat-loncat");
//     }
//     void fly(){
//         System.out.println("Burung Terbang...");
//     }
// }
//
// Enemy monster = new Enemy();
// Zombie zumbi = new Zombie();
// Pocong hantuPocong = new Pocong();
// Burung garuda = new Burung();
// ```

// %%
//Program 13.1

// %% [markdown]
// ### 13.2.2. Metode Overriding
//
// Method Overriding dilakukan saat kita ingin membuat ulang sebuah method pada sub-class atau class anak.
//
// Method Overriding dapat dibuat dengan menambahkan anotasi *@Override* di atas nama method atau sebelum pembuatan method.
//
// Berikut ini adalah contoh program penerapan overide dalam konsep pewarisan.
//
// Pertama karus di buat kelas induk. Dalam Kasus bangun datar, kita buat class BangunDatar dengan kode sebagai berikut.
//
// ```javascript
// class BangunDatar {
//
//     float luas(){
//         System.out.println("Menghitung laus bangun datar");
//         return 0;
//     }
//
//     float keliling(){
//         System.out.println("Menghitung keliling bangun datar");
//         return 0;
//     }
//
// }
// ```
// Kemudian Class Persegi yang melakukan penurunan dari class BangunDatar
//
// ```javascript
// class Persegi extends BangunDatar {
//     float sisi;
//
//     @Override
//     float luas(){
//         float luas = sisi * sisi;
//         System.out.println("Luas Persegi: " + luas);
//         return luas;
//     }
//
//     @Override
//     float keliling(){
//         float keliling = 4 * sisi;
//         System.out.println("Keliling Persegi: " + keliling);
//         return keliling;
//     }
// }
// ```
//
// Artinya kita menulis ulang method luas() dan keliling() di class anak.
//
// Sekarang mari kita buat method overriding untuk semua class anak.
//
// Class Lingkaran dengan struktur sebagai berikut.
//
// ```javascript
// class Lingkaran extends BangunDatar{
//
//     // jari-jari lingkaran
//     float r;
//
//     @Override
//     float luas(){
//         float luas = (float) (Math.PI * r * r);
//         System.out.println("Luas lingkaran: " + luas);
//         return luas;
//     }
//
//     @Override
//     float keliling(){
//         float keliling = (float) (2 * Math.PI * r);
//         System.out.println("Keliling Lingkaran: " + keliling);
//         return keliling;
//     }
//
// }
// ```
// Dalam rumus luas dan keliling lingkaran, kita bisa memanfaatkan konstanta Math.PI sebagai nilai PI. Konstanta ini sudah ada di Java.
//
// Pada class PersegiPanjang dengan struktur sebagai berikut
//
// ```javascript
// class PersegiPanjang extends BangunDatar {
//     float panjang;
//     float lebar;
//
//     @Override
//     float luas(){
//         float luas = panjang * lebar;
//         System.out.println("Luas Persegi Panjang:" + luas);
//         return luas;
//     }
//
//     @Override
//     float keliling(){
//         float kll = 2*panjang + 2*lebar;
//         System.out.println("Keliling Persegi Panjang: " + kll);
//         return kll;
//     }
// }
// ```
// Sedangkan class Segitiga dengan struktur sebagai berikut
//
// ```javascript
// class Segitiga extends BangunDatar {
//
//     float alas;
//     float tinggi;
//
//     @Override
//     float luas() {
//         float luas = 1/2 * (alas * tinggi);
//         System.out.println("Luas Segitiga: " + luas);
//         return luas;
//     }
//
// }
// ```
// Untuk class Segitiga, kita hanya melakukan override terhadap method luas() saja. Karena untuk method keliling(), segitiga memiliki rumus yang berbeda-beda.
//
//
// Bisa juga dari  class segitiga diturunkan lagi menjadi SegitigaSiku, SegitigaSamaKaki, SegitigaSamaSisi, dsb.
//
// Mari kita coba implementasikan pewarisan dengan metode overide
//
// **Program 13.2 Implementasi Overide Pada Pewarisan**
// ```javascript
//
//         // membuat objek bangun datar
//         BangunDatar bangunDatar = new BangunDatar();
//
//         // membuat objek persegi dan mengisi nilai properti
//         Persegi persegi = new Persegi();
//         persegi.sisi = 2;
//
//         // membuat objek Lingkaran dan mengisi nilai properti
//         Lingkaran lingkaran = new Lingkaran();
//         lingkaran.r = 22;
//
//         // membuat objek Persegi Panjang dan mengisi nilai properti
//         PersegiPanjang persegiPanjang = new PersegiPanjang();
//         persegiPanjang.panjang = 8;
//         persegiPanjang.lebar = 4;
//
//         // membuat objek Segitiga dan mengisi nilai properti
//         Segitiga mSegitiga = new Segitiga();
//         mSegitiga.alas = 12;
//         mSegitiga.tinggi = 8;
//
//
//         // memanggil method luas dan keliling
//         bangunDatar.luas();
//         bangunDatar.keliling();
//
//         persegi.luas();
//         persegi.keliling();
//
//         lingkaran.luas();
//         lingkaran.keliling();
//
//         persegiPanjang.luas();
//         persegiPanjang.keliling();
//
//         mSegitiga.luas();
//         mSegitiga.keliling();
// ```

// %%
//Program 13.2 Implementasi Overide
